# %%
import os
HOME=os.getcwd()
print(HOME)
from ultralytics import YOLO
from IPython.display import display,Image
# Out:
# /home/navid/deep_learning/fire_detection_yolo

# %%
# %cd {HOME}
import cv2
from ultralytics import YOLO
# Open video file
video_path = "/home/navid/deep_learning/fire_detection_yolo/videos/fire1.mp4"
cap = cv2.VideoCapture(video_path)
# Load YOLO model from the specified path
model = YOLO("/home/navid/deep_learning/fire_detection_yolo/weights/best.pt","v8")

results=model.track(source="/home/navid/deep_learning/fire_detection_yolo/videos/fire2.mp4",show=True,save=True)
print(results)
# Out:
# /home/navid/deep_learning/fire_detection_yolo
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/296) /home/navid/deep_learning/fire_detection_yolo/videos/fire2.mp4: 800x480 (no detections), 117.3ms
# video 1/1 (2/296) /home/navid/deep_learning/fire_detection_yolo/videos/fire2.mp4: 800x480 (no detections), 11.2ms
# video 1/1 (3/296) /home/navid/deep_learning/fire_detection_yolo/videos/fire2.mp4: 800x480 (no detections), 11.2ms
# ...

# %%
# Define the RTSP stream URL
rtsp_url = "rtsp://username:password@your_rtsp_stream_url"

# Create a VideoCapture object to open the stream
cap = cv2.VideoCapture(rtsp_url)
# Load YOLO model from the specified path
model = YOLO("/home/navid/deep_learning/fire_detection_yolo/weights/best.pt","v8")

results=model.track(source="rtsp://username:password@your_rtsp_stream_url",show=True,save=True)
print(results)

# %%
# Load YOLO model from the specified path
model = YOLO("/home/navid/deep_learning/fire_detection_yolo/weights/best.pt","v8")

results=model.track(source="/home/navid/deep_learning/fire_detection_yolo/videos/fire2.mp4",show=True,save=True)
print(results)
